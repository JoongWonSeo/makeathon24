# %%
from backend.db.products import product_db


await product_db.check_exist_and_initialize()
# Out:
# True

# %%
DIALOG_FORMAT = """
Dealer: "{dealer}"
Customer: "{customer}"
""".strip()

# %%
import itertools
res = product_db.iterate()

my_list = []
i = 0
async for product in res:
    i += 1
    if i > 50:
        break
    # print(product)
    my_list.append(product)

print(my_list)
# Out:
# [Product(name='Certified Pre-Owned 2016 Mercedes-Benz GLE 450 AMG   With Navigation', vehicle_type=<VehicleType.SUV: 'SUV'>, release_year=2016, price_in_usd=39998.0, is_used=True, powertrain_type=<Powertrain.ICE: 'ICE'>, num_seats=5, color='White', specs={'year': 2016, 'make': 'Mercedes-Benz', 'model': 'GLE-Class Coupe', 'trim': 'GLE450 AMG', 'body_type': 'SUV', 'vehicle_type': 'Truck', 'transmission': 'Automatic', 'drivetrain': '4WD', 'fuel_type': 'Premium Unleaded', 'engine': '3.0L V6', 'engine_size': 3, 'engine_block': 'V', 'doors': 5, 'cylinders': 6, 'made_in': 'USA', 'overall_height': '67.7', 'overall_length': '192.6', 'std_seating': '5', 'highway_mpg': 23, 'city_mpg': 17, 'powertrain_type': 'Combustion'}, image_url=['https://relay.marketcheck.com/image/us/cars/4JGED6EB5GA040419-4b0a48d6-1d43/8836ED6E', 'https://vehicle-images.dealerinspire.com/aa36-110011766/4JGED6EB5GA040419/9c697cc3abff89ae440f0d0de8366567.jpg', 'https://vehicle-images.dealerinspire.com/3b56-110011766/4JGED6EB5GA040419/0c42ea2f20d23a08fa5e80c553b38677.jpg', 'https://vehicle-images.dealerinspire.com/3375-110011766/4JGED6EB5GA040419/bc4740d2ee99cd55216f766557605fb4.jpg', 'https://vehicle-images.dealerinspire.com/9597-110011766/4JGED6EB5GA040419/7b4f06013881b17c9141e16e44f09c3c.jpg', 'https://vehicle-images.dealerinspire.com/bdbd-110011766/4JGED6EB5GA040419/47d99ebf59dd313024d61d23466ea2ce.jpg', 'https://vehicle-images.dealerinspire.com/48f4-110011766/4JGED6EB5GA040419/44fff60b7aeb8bb825f6119dd6250f88.jpg', 'https://vehicle-images.dealerinspire.com/80b4-110011766/4JGED6EB5GA040419/61f68fdf11ac3d06584d00645a8fc459.jpg', 'https://vehicle-images.dealerinspire.com/da55-110011766/4JGED6EB5GA040419/7e3ae2d1f584e2967cd5d0dedb64abdc.jpg', 'https://vehicle-images.dealerinspire.com/92af-110011766/4JGED6EB5GA040419/73810e212581743a2ed69b4c5574df54.jpg']), Product(name='2020 Mercedes-Benz GLC 300 Coupe  SUV', vehicle_type=<VehicleType.SUV: 'SUV'>, release_year=2020, price_in_usd=40880.0, is_used=True, powertrain_type=<Powertrain.ICE: 'ICE'>, num_seats=5, color='White', specs={'year': 2020, 'make': 'Mercedes-Benz', 'model': 'GLC Coupe', 'trim': 'GLC300', 'body_type': 'SUV', 'vehicle_type': 'Truck', 'transmission': 'Automatic', 'drivetrain': '4WD', 'fuel_type': 'Premium Unleaded', 'engine': '2.0L I4', 'engine_size': 2, 'engine_block': 'I', 'doors': 5, 'cylinders': 4, 'made_in': 'USA', 'overall_height': '63.1', 'overall_length': '186.3', 'overall_width': '74.4', 'std
# %%
import logging
import json

from agentools import ChatGPT, SimpleHistory, msg

EXTRACTOR_SYSTEM = """
The Customer wants to buy a car. The Customer talks with a dealer to find the car that fits his needs. The Customer gives out information about the car he wants and about himself. 

You are a third party that listens to the conversation. You have a conversation history between the Customer and the dealer.

Guess what the Customer is looking for in a car, as concise as possible. Gather what you know about the Customer and build up your guess based on the previous conversations. If your previous answer is still relevant, you must include it again in the new response. Add or modify the previous knowledge based on the new information.

PREVIOUS GUESS:
{user_data}
""".strip()


RECOMMENDER_SYSTEM = """
A customer wants to buy a car. Return at most three cars from the given list of cars that best match the customer's preferences. You MUST stick to the given list. Recommend electric cars first, then hybrid cars, and then gasoline cars. If there are multiple cars of the same type, recommend the one with the lowest price first.

If you can't find any that match the customer's preferences, return {{"No Recommendation": "true", "reason": "Why there isn't any recommendation"}}. Answer in the following json format:
{{
    "rank_1": {{
        id: "id1",
        "name": "car1",
        "vehicle_type": "vehicle_type1",
        "reason": "the reason why this car is recommended",
    }},
    "rank_2": {{
        id: "id2",
        "name": "car2",
        "vehicle_type": "vehicle_type2",
        "reason": "the reason why this car is recommended",
    }},
    "rank_3": {{
        id: "id3",
        "name": "car3",
        "vehicle_type": "vehicle_type3",
        "reason": "the reason why this car is recommended",
    }}
}}

CUSTOMER PREFERENCES:
{preference}
""".strip()

MODEL = "gpt-4-turbo"
# MODEL = "llama3-8b-8192"



class RecommenderHistory(SimpleHistory):
    def __init__(self, system_message):
        self._history = []
        self._system_message = system_message
        self.preference = ""


    @property
    def history(self):
        return [msg(
            system=self._system_message.format(preference=self.preference)), *self._history]
        
    async def append(self, message):
        # called by the assistant
        message = self.ensure_dict(message)
        self._history.append(message)

class Recommender():
    def __init__(self, user_data=None):
        self.preference = None # guess of user preferences
        
        messages=SimpleHistory.system(EXTRACTOR_SYSTEM.format(user_data=user_data or "None"))
        self.extractor = ChatGPT(messages=messages, model=MODEL)
        
        
        self.recommender_history=RecommenderHistory(RECOMMENDER_SYSTEM)
        self.recommender = ChatGPT(messages=self.recommender_history, model=MODEL)


    async def extract_preferences(self, dialog):
        extracted = await self.extractor(dialog)
        self.preference = extracted
        self.recommender_history.preference = extracted
        return extracted

    async def get_recommendation(self, products):
        # TODO: implement sorting based on preferences
        sorted = await self.recommender(products, response_format={ "type": "json_object" })
        return sorted
        # return json.loads(sorted)

# %%
recommender = Recommender()

# %%
async def get_preference(dealer, customer):
    dialog = DIALOG_FORMAT.format(dealer=dealer, customer=customer)
    return await recommender.extract_preferences(dialog)

# %%
pr = await get_preference(dealer="Hello, how can I help you?", customer="I am looking for a new car")
print(pr)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The Customer is looking for a new car.

# %%
pr = await get_preference(dealer="You came to the right place! What kind of car are you looking for?", customer="I want an SUV to replace my old car, my wife just gave birth and we wanted to buy a bigger car for the family")
print(pr)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The Customer is looking for a new SUV to accommodate his growing family, following the birth of a new child.

# %%
pr = await get_preference(dealer="I see. You can take a look at our offerings of EQE and EQS here. What do you think?", customer="This car will mostly be used for commute, so I was thinking of a car that is more simple.")
print(pr)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The Customer is looking for a new, simple SUV that is suitable for daily commutes and can accommodate his growing family.

# %%
pr = await get_preference(dealer="We also provide great electric cars for commuting. What do you think of EXA?", customer="You know what, forget about everything I said, I want a luxury car. I want to feel like a king when I drive it.")
print(pr)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The Customer is now looking for a luxury car that offers a high level of comfort and a prestigious driving experience, indicating a shift from his original preference for a simple, family-oriented SUV.

# %%
pr = await get_preference(dealer="We also provide great electric cars for commuting. What ", customer="This car will mostly be used for commute, so I was thinking of a car that is more simple.")
print(pr)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The Customer is looking for a new, simple car that is efficient for daily commutes and comfortable enough for his growing family, rather than a luxury vehicle.

# %%
from pprint import pprint

car_list = []
for i, car in enumerate(my_list[:20]):
    car = car.model_dump()
    car.pop("image_url")
    c = {i: car}
    car_list.append(c)

# %%
recommender.recommender_history.preference = "The Customer is looking for a simple, straightforward SUV for their daily commute, prioritizing practicality and ease of use over luxury or high-tech features."
rc = await recommender.get_recommendation(f"LIST OF CARS: {json.dumps(car_list, indent=2)}")

print(rc)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {
#     "rank_1": {
#         "id": "3",
#         "name": "2023 Mercedes-Benz EQB EQB 300 4MATIC",
#         "vehicle_type": "SUV",
#         "reason": "This electric SUV is recommended for its balance between price, functionality, and electric vehicle benefits, aligning with the practical and straightforward preferences."
#     },
#     "rank_2": {
#         "id": "14",
#         "name": "Certified Pre-Owned 2023 Mercedes-Benz EQE 500 AWD 4MATIC",
#         "vehicle_type": "SUV",
#         "reason": "Although priced higher, this certified pre-owned electric SUV offers an all-wheel-drive option and effective use for daily commuting."
#     },
#     "rank_3": {
#         "id": "12",
#         "name": "2023 Mercedes-Benz GLA 250 SUV",
#         "vehicle_type": "SUV",
#         "reason": "This hybrid SUV is selected for its fuel efficiency and more affordable price among hybrids, providing a mixture of practicality with reduced environmental impact."
#     }
# }

# %%
print(f"LIST OF CARS: {json.dumps(car_list, indent=2)}")
# Out:
# LIST OF CARS: [
#   {
#     "0": {
#       "name": "Certified Pre-Owned 2016 Mercedes-Benz GLE 450 AMG   With Navigation",
#       "vehicle_type": "SUV",
#       "release_year": 2016,
#       "price_in_usd": 39998.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 5,
#       "color": "White",
#       "specs": {
#         "year": 2016,
#         "make": "Mercedes-Benz",
#         "model": "GLE-Class Coupe",
#         "trim": "GLE450 AMG",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "3.0L V6",
#         "engine_size": 3,
#         "engine_block": "V",
#         "doors": 5,
#         "cylinders": 6,
#         "made_in": "USA",
#         "overall_height": "67.7",
#         "overall_length": "192.6",
#         "std_seating": "5",
#         "highway_mpg": 23,
#         "city_mpg": 17,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "1": {
#       "name": "2020 Mercedes-Benz GLC 300 Coupe  SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2020,
#       "price_in_usd": 40880.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 5,
#       "color": "White",
#       "specs": {
#         "year": 2020,
#         "make": "Mercedes-Benz",
#         "model": "GLC Coupe",
#         "trim": "GLC300",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "63.1",
#         "overall_length": "186.3",
#         "overall_width": "74.4",
#         "std_seating": "5",
#         "highway_mpg": 27,
#         "city_mpg": 21,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "2": {
#       "name": "2023 Mercedes-Benz EQE 350+  SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2023,
#       "price_in_usd": 67428.0,
#       "is_used": true,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "Black",
#       "specs": {
#         "year": 2023,
#         "make": "Mercedes-Benz",
#         "model": "EQE SUV",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "RWD",
#         "fuel_type": "Electric",
#         "doors": 5,
#         "made_in": "USA",
#         "overall_height": "66.3",
#         "overall_length": "191.5",
#         "overall_width": "76.4",
#         "std_seating": "5",
#         "highway_mpg": 87,
#         "city_mpg": 94,
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "3": {
#       "name": "2023 Mercedes-Benz EQB EQB 300 4MATIC",
#       "vehicle_type": "SUV",
#       "release_year": 2023,
#       "price_in_usd": 51487.0,
#       "is_used": true,
#       "powertrain_type": "EV",
#       "num_seats": 7,
#       "color": "Black",
#       "specs": {
#         "year": 2023,
#         "make": "Mercedes-Benz",
#         "model": "EQB",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Electric",
#         "doors": 5,
#         "made_in": "USA",
#         "overall_height": "65.6",
#         "overall_length": "184.4",
#         "std_seating": "7",
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "4": {
#       "name": "New 2023 Mercedes-Benz EQE 350 SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2023,
#       "price_in_usd": 81385.0,
#       "is_used": false,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "Black",
#       "specs": {
#         "year": 2023,
#         "make": "Mercedes-Benz",
#         "model": "EQE SUV",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Electric",
#         "doors": 5,
#         "made_in": "USA",
#         "overall_height": "66.3",
#         "overall_length": "191.5",
#         "overall_width": "76.4",
#         "std_seating": "5",
#         "highway_mpg": 79,
#         "city_mpg": 82,
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "5": {
#       "name": "2022 Mercedes-Benz EQS EQS 450+ Sedan Sedan",
#       "vehicle_type": "Hatchback",
#       "release_year": 2022,
#       "price_in_usd": 53989.0,
#       "is_used": true,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "Gray",
#       "specs": {
#         "year": 2022,
#         "make": "Mercedes-Benz",
#         "model": "EQS",
#         "trim": "Base",
#         "body_type": "Hatchback",
#         "vehicle_type": "Car",
#         "transmission": "Automatic",
#         "drivetrain": "RWD",
#         "fuel_type": "Electric",
#         "doors": 4,
#         "made_in": "USA",
#         "overall_height": "59.6",
#         "overall_length": "207.3",
#         "overall_width": "75.8",
#         "std_seating": "5",
#         "highway_mpg": 97,
#         "city_mpg": 97,
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "6": {
#       "name": "2021 Mercedes-Benz GLA 250 GLA 250 SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2021,
#       "price_in_usd": 30999.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 5,
#       "color": "White",
#       "specs": {
#         "year": 2021,
#         "make": "Mercedes-Benz",
#         "model": "GLA",
#         "trim": "GLA250",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "63.5",
#         "overall_length": "173.6",
#         "overall_width": "72.2",
#         "std_seating": "5",
#         "highway_mpg": 33,
#         "city_mpg": 24,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "7": {
#       "name": "2010 Mercedes-Benz E-Class E350 Coupe",
#       "vehicle_type": "Coupe",
#       "release_year": 2010,
#       "price_in_usd": 10995.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 4,
#       "color": "White",
#       "specs": {
#         "year": 2010,
#         "make": "Mercedes-Benz",
#         "model": "E-Class",
#         "trim": "E350",
#         "body_type": "Coupe",
#         "vehicle_type": "Car",
#         "transmission": "Automatic",
#         "drivetrain": "RWD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "3.5L V6",
#         "engine_size": 3.5,
#         "engine_block": "V",
#         "doors": 2,
#         "cylinders": 6,
#         "made_in": "USA",
#         "overall_height": "54.0",
#         "overall_length": "184.9",
#         "overall_width": "70.3",
#         "std_seating": "4",
#         "highway_mpg": 26,
#         "city_mpg": 17,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "8": {
#       "name": "2014 Mercedes-benz CLA-Class Coupe",
#       "vehicle_type": "Sedan",
#       "release_year": 2014,
#       "price_in_usd": 12995.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 5,
#       "color": "Black",
#       "specs": {
#         "year": 2014,
#         "make": "Mercedes-Benz",
#         "model": "CLA-Class",
#         "trim": "CLA250",
#         "body_type": "Sedan",
#         "vehicle_type": "Car",
#         "transmission": "Automatic",
#         "drivetrain": "FWD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 4,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "56.6",
#         "overall_length": "182.3",
#         "overall_width": "70.0",
#         "std_seating": "5",
#         "highway_mpg": 38,
#         "city_mpg": 26,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "9": {
#       "name": "2024 Mercedes-Benz GLE 350 4MATIC SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2024,
#       "price_in_usd": 67998.0,
#       "is_used": true,
#       "powertrain_type": "Hybrid",
#       "num_seats": 7,
#       "color": "White",
#       "specs": {
#         "year": 2024,
#         "make": "Mercedes-Benz",
#         "model": "GLE",
#         "trim": "GLE350",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "70.7",
#         "overall_length": "194.3",
#         "overall_width": "76.7",
#         "std_seating": "7",
#         "highway_mpg": 27,
#         "city_mpg": 20,
#         "powertrain_type": "MHEV"
#       }
#     }
#   },
#   {
#     "10": {
#       "name": "New 2024 Mercedes-Benz EQE",
#       "vehicle_type": "SUV",
#       "release_year": 2024,
#       "price_in_usd": 87315.0,
#       "is_used": false,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "Blue",
#       "specs": {
#         "year": 2024,
#         "make": "Mercedes-Benz",
#         "model": "EQE SUV",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "RWD",
#         "fuel_type": "Electric",
#         "doors": 5,
#         "made_in": "USA",
#         "overall_height": "65.8",
#         "overall_length": "191.5",
#         "overall_width": "76.4",
#         "std_seating": "5",
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "11": {
#       "name": "New 2024 Mercedes-Benz EQE 350+ SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2024,
#       "price_in_usd": 80235.0,
#       "is_used": false,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "White",
#       "specs": {
#         "year": 2024,
#         "make": "Mercedes-Benz",
#         "model": "EQE SUV",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "RWD",
#         "fuel_type": "Electric",
#         "doors": 5,
#         "made_in": "USA",
#         "overall_height": "65.8",
#         "overall_length": "191.5",
#         "overall_width": "76.4",
#         "std_seating": "5",
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "12": {
#       "name": "2023 Mercedes-Benz GLA 250  SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2023,
#       "price_in_usd": 39480.0,
#       "is_used": true,
#       "powertrain_type": "Hybrid",
#       "num_seats": 5,
#       "color": "Gray",
#       "specs": {
#         "year": 2023,
#         "make": "Mercedes-Benz",
#         "model": "GLA",
#         "trim": "GLA250",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Manual",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "63.5",
#         "overall_length": "173.6",
#         "overall_width": "72.2",
#         "std_seating": "5",
#         "highway_mpg": 32,
#         "city_mpg": 23
#       }
#     }
#   },
#   {
#     "13": {
#       "name": "2010 Mercedes-Benz CL-Class 2dr Cpe CL 550 4MATIC",
#       "vehicle_type": "Coupe",
#       "release_year": 2010,
#       "price_in_usd": 12999.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 4,
#       "color": "Silver",
#       "specs": {
#         "year": 2010,
#         "make": "Mercedes-Benz",
#         "model": "CL-Class",
#         "trim": "CL550",
#         "body_type": "Coupe",
#         "vehicle_type": "Car",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "5.5L V8",
#         "engine_size": 5.5,
#         "engine_block": "V",
#         "doors": 2,
#         "cylinders": 8,
#         "made_in": "USA",
#         "overall_height": "55.8",
#         "overall_length": "199.4",
#         "std_seating": "4",
#         "highway_mpg": 21,
#         "city_mpg": 14,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "14": {
#       "name": "Certified Pre-Owned 2023 Mercedes-Benz EQE 500 AWD 4MATIC",
#       "vehicle_type": "SUV",
#       "release_year": 2023,
#       "price_in_usd": 74888.0,
#       "is_used": true,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "Blue",
#       "specs": {
#         "year": 2023,
#         "make": "Mercedes-Benz",
#         "model": "EQE SUV",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Electric",
#         "doors": 5,
#         "made_in": "USA",
#         "overall_height": "66.3",
#         "overall_length": "191.5",
#         "overall_width": "76.4",
#         "std_seating": "5",
#         "highway_mpg": 86,
#         "city_mpg": 91,
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "15": {
#       "name": "Pre-Owned 2023 Mercedes-Benz EQS 450",
#       "vehicle_type": "Hatchback",
#       "release_year": 2023,
#       "price_in_usd": 67088.0,
#       "is_used": true,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "White",
#       "specs": {
#         "year": 2023,
#         "make": "Mercedes-Benz",
#         "model": "EQS",
#         "trim": "Base",
#         "body_type": "Hatchback",
#         "vehicle_type": "Car",
#         "transmission": "Automatic",
#         "drivetrain": "RWD",
#         "fuel_type": "Electric",
#         "doors": 4,
#         "made_in": "USA",
#         "overall_height": "59.6",
#         "overall_length": "207.3",
#         "overall_width": "75.8",
#         "std_seating": "5",
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "16": {
#       "name": "2024 Mercedes-Benz GLE 350 GLE 350 SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2024,
#       "price_in_usd": 59999.0,
#       "is_used": true,
#       "powertrain_type": "Hybrid",
#       "num_seats": 7,
#       "color": "White",
#       "specs": {
#         "year": 2024,
#         "make": "Mercedes-Benz",
#         "model": "GLE",
#         "trim": "GLE350",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "70.7",
#         "overall_length": "194.3",
#         "overall_width": "76.7",
#         "std_seating": "7",
#         "highway_mpg": 27,
#         "city_mpg": 20,
#         "powertrain_type": "MHEV"
#       }
#     }
#   },
#   {
#     "17": {
#       "name": "2020 Mercedes-Benz GLB 250  SUV",
#       "vehicle_type": "SUV",
#       "release_year": 2020,
#       "price_in_usd": 30380.0,
#       "is_used": true,
#       "powertrain_type": "ICE",
#       "num_seats": 7,
#       "color": "Silver",
#       "specs": {
#         "year": 2020,
#         "make": "Mercedes-Benz",
#         "model": "GLB",
#         "trim": "Base",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "65.3",
#         "overall_length": "182.4",
#         "overall_width": "72.2",
#         "std_seating": "7",
#         "highway_mpg": 31,
#         "city_mpg": 23,
#         "powertrain_type": "Combustion"
#       }
#     }
#   },
#   {
#     "18": {
#       "name": "New 2024 Mercedes-Benz EQE",
#       "vehicle_type": "Sedan",
#       "release_year": 2024,
#       "price_in_usd": 84250.0,
#       "is_used": false,
#       "powertrain_type": "EV",
#       "num_seats": 5,
#       "color": "Silver",
#       "specs": {
#         "year": 2024,
#         "make": "Mercedes-Benz",
#         "model": "EQE",
#         "trim": "Base",
#         "body_type": "Sedan",
#         "vehicle_type": "Car",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Electric",
#         "doors": 4,
#         "made_in": "USA",
#         "overall_height": "59.5",
#         "overall_length": "196.9",
#         "overall_width": "77.2",
#         "std_seating": "5",
#         "highway_mpg": 86,
#         "city_mpg": 86,
#         "powertrain_type": "BEV"
#       }
#     }
#   },
#   {
#     "19": {
#       "name": "Certified 2024 Mercedes-Benz GLC",
#       "vehicle_type": "SUV",
#       "release_year": 2024,
#       "price_in_usd": 54988.0,
#       "is_used": true,
#       "powertrain_type": "Hybrid",
#       "num_seats": 5,
#       "color": "Silver",
#       "specs": {
#         "year": 2024,
#         "make": "Mercedes-Benz",
#         "model": "GLC",
#         "trim": "GLC 300",
#         "body_type": "SUV",
#         "vehicle_type": "Truck",
#         "transmission": "Automatic",
#         "drivetrain": "4WD",
#         "fuel_type": "Premium Unleaded",
#         "engine": "2.0L I4",
#         "engine_size": 2,
#         "engine_block": "I",
#         "doors": 5,
#         "cylinders": 4,
#         "made_in": "USA",
#         "overall_height": "64.6",
#         "overall_length": "185.7",
#         "overall_width": "74.4",
#         "std_seating": "5",
#         "highway_mpg": 32,
#         "city_mpg": 24,
#         "powertrain_type": "MHEV"
#       }
#     }
#   }
# ]
